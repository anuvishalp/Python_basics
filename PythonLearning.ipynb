# %% [markdown]
# <a href="https://colab.research.google.com/github/anuvishalp/Python_basics/blob/main/PythonLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
####Complete Python Tutorial--->>>>

1. Tasks under Variables & Types

          Assigning variables
          Type identification (type())
          Type conversion (casting)
          Arithmetic with variables
          String + number interactions
          Multiple assignment
          Swapping variables
          Mutable vs immutable behavior
          Input → variable conversion
          Constants & naming conventions

✅ 2. Multi‑Scenario Examples for Each Task
=========================
Task 1 — Assigning Variables
        Scenario A: Basic assignment
                x = 10
                name = "Anu"
                pi = 3.14
        Scenario B: Assigning expressions
                total = 5 + 7
                message = "Hello " + "World"
        Scenario C: Assigning based on conditions
        is_valid = True if 5 > 3 else False
=======================
Task 2 — Type Identification

        Scenario A
            type(10)        # int
            type(3.14)      # float
            type("hello")   # str
        Scenario B: Custom object
            class A: pass
            obj = A()
            type(obj)       # <class '__main__.A'>
=========================
Task 3 — Type Conversion (Casting)
      Scenario A: String → int
          age = int("25")
      Scenario B: Float → int
          x = int(3.99)   # 3
      Scenario C: Number → string
          s = str(123)
=========================
Task 4 — Arithmetic with Variables
      Scenario A
            a = 10
            b = 3
            result = a // b   # integer division
      Scenario B: Modulo
            rem = 17 % 5
      Scenario C: Power
            x = 2 ** 10
=========================
Task 5 — String + Number Interactions
          Scenario A: Invalid
                "Age: " + 25   # ❌ TypeError
          Scenario B: Correct
                "Age: " + str(25)
          Scenario C: Using f‑strings
                f"Age: {25}"
=========================
Task 6 — Multiple Assignment
        Scenario A
              a, b = 10, 20
        Scenario B
              x = y = z = 0
=========================
Task 7 — Swapping Variables
        Scenario A
              a, b = b, a
        Scenario B: Without tuple unpacking
              temp = a
              a = b
              b = temp
=========================
Task 8 — Mutable vs Immutable
        Scenario A: Immutable (int)
              x = 10
              y = x
              x = 20
              # y remains 10
        Scenario B: Mutable (list)
              a = [1, 2, 3]
              b = a
              a.append(4)
              # b also becomes [1,2,3,4]
=========================
Task 9 — Input → Variable Conversion
        Scenario A
                age = int(input("Enter age: "))
        Scenario B
                price = float(input("Enter price: "))
=========================
Task 10 — Constants & Naming Conventions
        Scenario A
              PI = 3.14159
              MAX_USERS = 100
        Scenario B
              user_name = "Anu"   # snake_case
=========================
🎯 3. 20 Questions for Topic 1 — Variables & Types

        Assign a variable x with value 50.
        What is the type of 3.14?
        Convert the string "123" into an integer.
        Convert the integer 45 into a string.
        What is the result of 10 // 3?
        What is the result of 17 % 5?
        Write a Python expression to compute 2^8.
        Assign variables a=10, b=20 in one line.
        Swap variables x and y without using a temporary variable.
        Why is an integer considered immutable?
        Demonstrate mutability using a list.
        Convert user input "45.6" into a float.
        What happens when you run "Age: " + 25?
        Fix the above expression so it works.
        Write an f‑string that prints "Score: 95".
        Assign the same value 0 to variables p, q, and r.
        What is the type of True?
        What is the type of None?
        Write a variable name following Python naming conventions for storing a user’s email.
        Explain the difference between = and ==

# %%
#####⭐ TOPIC 2 — LISTS
Tasks:

Create lists
Indexing
Slicing
Append
Insert
Remove / pop
Iterate through lists
Search in lists
Sorting
Nested lists
Copying lists (shallow vs deep)
Using lists with loops
=========================
✅ 1. Multi‑Scenario Examples for Each Task
Task 1 — Create Lists

          Scenario A: Basic numeric list
                nums = [1, 2, 3, 4]
          Scenario B: Mixed‑type list
                info = ["Anu", 20, True, 3.14]
          Scenario C: Empty list
                items = []
          Scenario D: List from range
                nums = list(range(5))   # [0,1,2,3,4]
=========================
Task 2 — Indexing

          Scenario A: Positive indexing
                  nums = [10, 20, 30, 40]
                  nums[0]   # 10
                  nums[2]   # 30
          Scenario B: Negative indexing
                  nums[-1]  # 40
                  nums[-2]  # 30
          Scenario C: Index assignment
                  nums[1] = 99   # [10, 99, 30, 40]
=========================
Task 3 — Slicing
          Scenario A: Basic slice
                  nums[1:3]   # [20, 30]
          Scenario B: Slice from start
                  nums[:2]    # [10, 20]
          Scenario C: Slice to end
                  nums[2:]    # [30, 40]
          Scenario D: Step slicing
                  nums[::2]   # [10, 30]
                  nums[::2]   # every second element
=========================
Task 4 — Append
          Scenario A
                    nums.append(50)
          Scenario B: Append list as element
                    nums.append([60, 70])   # nested list inside
=========================
Task 5 — Insert
          Scenario A
                  nums.insert(1, 15)
          Scenario B: Insert at beginning
                  nums.insert(0, 5)
=========================
Task 6 — Remove / Pop

          Scenario A: Remove by value
                nums.remove(20)
          Scenario B: Pop last
                nums.pop()
          Scenario C: Pop by index
                nums.pop(1)
=========================
Task 7 — Iterate Through Lists
          Scenario A: Direct iteration
                  for x in nums:
                      print(x)
          Scenario B: Index-based
                  for i in range(len(nums)):
                      print(nums[i])
          Scenario C: While loop
                i = 0
                while i < len(nums):
                    print(nums[i])
                    i += 1
=========================
Task 8 — Search in Lists

          Scenario A: Using in
                  20 in nums
          Scenario B: Using .index()
                  nums.index(30)
          Scenario C: Count occurrences
                  nums.count(10)
=========================
Task 9 — Sorting
          Scenario A: Ascending
                  nums.sort()
          Scenario B: Descending
                  nums.sort(reverse=True)
          Scenario C: Sorted copy
                  new_list = sorted(nums)
=========================
Task 10 — Nested Lists

Scenario A
        matrix = [
            [1, 2],
            [3, 4]
        ]
        matrix[1][0]   # 3
Scenario B: 3‑level nesting
        data = [1, [2, [3, 4]]]
        data[1][1][0]  # 3
=========================
Task 11 — Copying Lists (Shallow vs Deep)

Scenario A: Shallow copy
          a = [1, 2, [3, 4]]
          b = a.copy()
          a[2].append(5)
          # b also changes → [1,2,[3,4,5]]
Scenario B: Deep copy
        import copy
        a = [1, 2, [3, 4]]
        b = copy.deepcopy(a)
        a[2].append(5)
        # b stays unchanged
=========================
Task 12 — Using Lists with Loops

Scenario A: Build list using loop
        nums = []
        for i in range(5):
            nums.append(i*i)
Scenario B: Filter list using loop
        evens = []
        for x in nums:
            if x % 2 == 0:
                evens.append(x)
=========================
🎯 2. 20 Questions — LISTS

              Create a list of 5 numbers.
              Access the 3rd element of a list.
              Slice the first 3 elements.
              Append 100 to a list.
              Insert 50 at index 1.
              Remove the value 20.
              Pop the last element.
              Pop the element at index 2.
              Iterate and print all elements.
              Iterate using index.
              Get the last element using negative index.
              Replace the 2nd element with 99.
              Create an empty list.
              Extend a list with [7,8,9].
              Sort a list in descending order.
              Reverse a list.
              Count occurrences of a value.
              Find index of a value.
              Check if 25 exists in a list.
              Create a nested list and access an inner element.

# %%
####TOPIC 3 — BASIC OPERATORS

Tasks:
Arithmetic operations
Comparison operators
Boolean logic
Operator precedence

✅ 1. Multi‑Scenario Examples for Each Task
Task 1 — Arithmetic Operations
          Scenario A: Basic arithmetic
          python
          a = 10 + 5      # 15
          b = 10 - 3      # 7
          c = 10 * 2      # 20
          d = 10 / 4      # 2.5
          Scenario B: Floor division & modulo
          python
          10 // 3   # 3
          10 % 3    # 1
          Scenario C: Power
          python
          2 ** 5    # 32
          Scenario D: Mixed operations
          python
          result = (10 + 5) * 2 - 3
          Scenario E: Arithmetic with variables
          python
          x = 7
          y = 3
          z = x * y + 10
-=========================================
Task 2 — Comparison Operators
              Scenario A: Numeric comparisons
              python
                      5 > 3     # True
                      5 < 3     # False
                      5 == 5    # True
                      5 != 4    # True

              Scenario B: String comparisons
              python
                    "apple" < "banana"   # True (lexicographical)

              Scenario C: Comparing variables
              python
                      a = 10
                      b = 20
                      a <= b    # True
              Scenario D: Comparing different types
              python
                     10 == "10"   # False
============================================
Task 3 — Boolean Logic
            Scenario A: AND
                  True and False   # False
            Scenario B: OR
                  True or False    # True
            Scenario C: NOT
                  not True         # False
            Scenario D: Combined logic
                  (5 > 3) and (2 < 1)   # False
                  (5 > 3) or (2 < 1)    # True
            Scenario E: Boolean logic with variables
                  is_admin = True
                  is_active = False
                  is_allowed = is_admin and is_active
============================================
Task 4 — Operator Precedence

        Scenario A: Multiplication before addition
        python
                2 + 3 * 4    # 14
        Scenario B: Using parentheses
        python
                (2 + 3) * 4  # 20
        Scenario C: Mixed precedence
        python
                10 - 3 * 2 + 1   # 5
        Scenario D: Boolean precedence
        python
                True or False and False   # True
                # because AND happens before OR
        Scenario E: Complex expression
        python
                result = (5 + 3) * 2 ** 2 - 10 // 3
============================================

🎯 2. 20 Questions — BASIC OPERATORS
          Compute 10 + 20.
          Compute 10 / 3.
          Compute 10 // 3.
          Compute 10 % 3.
          Compute 2**6.
          Evaluate 5 > 3.
          Evaluate 5 == 4.
          Evaluate 5 != 5.
          Evaluate True and False.
          Evaluate True or False.
          Evaluate not False.
          Evaluate 2 + 3 * 4.
          Evaluate (2 + 3) * 4.
          Compare "a" < "b".
          Compare 10 >= 10.
          Compare 3 <= 2.
          Evaluate (5 > 3) and (2 < 1).
          Evaluate (5 > 3) or (2 < 1).
          Explain operator precedence.
          Why is 10/3 different from 10//3?

# %%
###⭐ TOPIC 4 — STRINGS

Tasks:
Concatenate strings
Format strings
Slice strings
Use string methods
============================================
✅ 1. Multi‑Scenario Examples for Each Task

Task 1 — Concatenate Strings
          Scenario A: Basic concatenation
          python
          "Hello" + " " + "World"
          Scenario B: Concatenation with variables
          python
          first = "Anu"
          last = "Panthangi"
          full = first + " " + last
          Scenario C: Concatenation inside loops
          python
          result = ""
          for c in ["A", "B", "C"]:
              result += c
          # "ABC"
          Scenario D: Concatenation with non‑strings (incorrect)
          python
          "Age: " + 25   # ❌ TypeError
          Scenario E: Correct version
          python
          "Age: " + str(25)
============================================
Task 2 — Format Strings
          Scenario A: f‑strings (recommended)
          python
          name = "Anu"
          age = 20
          f"My name is {name} and I am {age} years old."
          Scenario B: format()
          python
          "Hello {}, you are {} years old".format(name, age)
          Scenario C: Named placeholders
          python
          "Name: {n}, Age: {a}".format(n=name, a=age)
          Scenario D: Formatting numbers
          python
          pi = 3.1415926
          f"{pi:.2f}"   # '3.14'
          Scenario E: Padding and alignment
          python
          f"{'Anu':>10}"   # right aligned
          f"{'Anu':<10}"   # left aligned
============================================
Task 3 — Slice Strings
          Scenario A: Basic slicing
          python
          s = "Python"
          s[0:3]   # 'Pyt'
          Scenario B: Slice to end
          python
          s[2:]    # 'thon'
          Scenario C: Slice from start
          python
          s[:4]    # 'Pyth'
          Scenario D: Negative slicing
          python
          s[-3:]   # 'hon'
          Scenario E: Step slicing
          python
          s[::2]   # 'Pto'
          Scenario F: Reverse string
          python
          s[::-1]  # 'nohtyP'
============================================
Task 4 — Use String Methods
          Scenario A: Case conversion
          python
          "hello".upper()      # 'HELLO'
          "HELLO".lower()      # 'hello'
          "python".capitalize() # 'Python'
          Scenario B: Searching
          python
          "hello world".find("world")   # 6
          "hello world".startswith("he") # True
          "hello world".endswith("ld")   # True
          Scenario C: Splitting and joining
          python
          "1,2,3".split(",")   # ['1','2','3']
          "-".join(["a","b"])  # 'a-b'
          Scenario D: Replace
          python
          "banana".replace("a", "o")   # 'bonono'
          Scenario E: Strip whitespace
          python
          "  hello  ".strip()   # 'hello'
          Scenario F: Validation methods
          python
          "123".isdigit()     # True
          "abc".isalpha()     # True
          "abc123".isalnum()  # True
          Scenario G: Count occurrences
          python
          "banana".count("a")   # 3
          Scenario H: Complex chaining
          python
          "  python  ".strip().upper().replace("P", "X")
============================================
🎯 2. 20 Questions — STRINGS

            Concatenate "Hello" and "World" with a space.
            Create an f‑string that prints "Age: 30".
            Format "Name: Anu" using .format().
            Slice "Python" to get "Pyt".
            Slice "Python" to get "hon".
            Reverse the string "Python".
            Convert "hello" to uppercase.
            Convert "HELLO" to lowercase.
            Replace "a" with "o" in "banana".
            Split "a,b,c" by comma.
            Join ["a","b","c"] into "a-b-c".
            Count occurrences of "a" in "banana".
            Check if "py" is in "python".
            Strip spaces from " hello ".
            Check if "123" is digit.
            Check if "Hello" starts with "H".
            Convert "python programming" to title case.
            Find index of "t" in "python".
            Replace spaces with underscores in "hello world".
            Extract domain from "anu@example.com".

# %%
####⭐ TOPIC 5 — CONDITIONS

Tasks:

Write if/elif/else
Boolean expressions
Nested conditions
============================================

✅ 1. Multi‑Scenario Examples for Each Task
            Task 1 — Write if/elif/else
            Scenario A: Basic if
            python
            age = 20
            if age >= 18:
                print("Adult")
            Scenario B: if/else
            python
            x = 5
            if x % 2 == 0:
                print("Even")
            else:
                print("Odd")
            Scenario C: if/elif/else
            python
            score = 85
            if score >= 90:
                print("A")
            elif score >= 80:
                print("B")
            else:
                print("C")
            Scenario D: Multiple elif
            python
            temp = 30
            if temp > 40:
                print("Very Hot")
            elif temp > 30:
                print("Hot")
            elif temp > 20:
                print("Warm")
            else:
                print("Cold")
            Scenario E: Using conditions with strings
            python
            name = "Anu"
            if name.startswith("A"):
                print("Starts with A")
============================================
Task 2 — Boolean Expressions
          Scenario A: Simple boolean
          python
          x = 10
          y = 20
          result = (x < y) and (y < 50)
          Scenario B: OR logic
          python
          user = "admin"
          if user == "admin" or user == "superuser":
              print("Access granted")
          Scenario C: NOT logic
          python
          is_active = False
          if not is_active:
              print("Inactive user")
          Scenario D: Combining multiple conditions
          python
          age = 25
          country = "USA"
          if age >= 18 and country == "USA":
              print("Eligible")
          Scenario E: Boolean expressions with functions
          python
          def is_even(n):
              return n % 2 == 0

          if is_even(10) and is_even(20):
              print("Both even")
============================================
Task 3 — Nested Conditions
            Scenario A: Basic nesting
            python
            age = 20
            citizen = True

            if age >= 18:
                if citizen:
                    print("Eligible to vote")
            Scenario B: Nested if/else
            python
            x = 10
            if x > 0:
                if x % 2 == 0:
                    print("Positive even")
                else:
                    print("Positive odd")
            Scenario C: Nested with multiple branches
            python
            user = "Anu"
            role = "admin"

            if user:
                if role == "admin":
                    print("Admin access")
                else:
                    print("User access")
            else:
                print("No user found")
            Scenario D: Nested conditions with input
            python
            age = 17
            parent_permission = True

            if age < 18:
                if parent_permission:
                    print("Allowed with permission")
                else:
                    print("Not allowed")
            Scenario E: Deep nesting (avoid in real code, but useful for teaching)
            python
            x = 5
            if x > 0:
                if x < 10:
                    if x % 5 == 0:
                        print("Special number")
============================================
🎯 2. 20 Questions — CONDITIONS

                  Write an if statement to check if a number is positive.
                  Write an if/else to check if a number is even or odd.
                  Write an if/elif/else to classify a score into A/B/C.
                  Check if a string starts with "A".
                  Check if a number is between 10 and 20.
                  Use OR to check if a user is "admin" or "manager".
                  Use NOT to check if a user is not active.
                  Combine conditions: age > 18 AND country == "USA".
                  Write a nested if to check if a number is positive and even.
                  Write a nested if to check if a user exists and is admin.
                  Check if "python" contains "py" using conditions.
                  Write a condition to check if a list is empty.
                  Write a condition to check if a number is divisible by 3 and 5.
                  Write a condition to check if a string ends with "ing".
                  Write a condition to check if a number is NOT zero.
                  Write a nested condition to check if age < 18 and has permission.
                  Write a condition to check if a variable is of type int.
                  Write a condition to check if a number is in a list.
                  Write a condition to check if two variables are equal.
                  Write a condition to check if a password length is >= 8.

# %%
####⭐ TOPIC 6 — LOOPS

Tasks:
For loops
While loops
Loop control (break/continue)
Looping with ranges
Looping with indexes
Looping through nested lists
Loop + condition combinations
Accumulators (sum, count, build lists)
Infinite loop patterns (safe examples)
Looping with else
============================================

✅ 1. Multi‑Scenario Examples for Each Task

Task 1 — For Loops
                Scenario A: Basic iteration
                python
                for x in [1, 2, 3]:
                    print(x)
                Scenario B: Looping through strings
                python
                for ch in "Python":
                    print(ch)
                Scenario C: Looping through dictionary keys
                python
                user = {"name": "Anu", "role": "Architect"}
                for key in user:
                    print(key)
                Scenario D: Looping through dictionary items
                python
                for key, value in user.items():
                    print(key, value)
                Scenario E: Looping through a range
                python
                for i in range(5):
                    print(i)
============================================
Task 2 — While Loops
          Scenario A: Basic while
          python
          i = 0
          while i < 5:
              print(i)
              i += 1
          Scenario B: Countdown
          python
          n = 5
          while n > 0:
              print(n)
              n -= 1
          Scenario C: While with user input
          python
          password = ""
          while password != "admin":
              password = input("Enter password: ")
          Scenario D: While with break
          python
          i = 0
          while True:
              if i == 3:
                  break
              i += 1
          Scenario E: While with continue
          python
          i = 0
          while i < 5:
              i += 1
              if i == 3:
                  continue
              print(i)
============================================
Task 3 — Loop Control (break / continue)
            Scenario A: break
            python
            for x in range(10):
                if x == 5:
                    break
                print(x)
            Scenario B: continue
            python
            for x in range(5):
                if x == 2:
                    continue
                print(x)
            Scenario C: break in nested loops
            python
            for i in range(3):
                for j in range(3):
                    if j == 1:
                        break
                    print(i, j)
            Scenario D: continue in nested loops
            python
            for i in range(3):
                for j in range(3):
                    if j == 1:
                        continue
                    print(i, j)
============================================
Task 4 — Looping with Ranges
            Scenario A: range(start, stop)
            python
            for i in range(2, 6):
                print(i)
            Scenario B: range(start, stop, step)
            python
            for i in range(0, 10, 2):
                print(i)
            Scenario C: Negative step
            python
            for i in range(10, 0, -2):
                print(i)
============================================
Task 5 — Looping with Indexes
            Scenario A: Using range + len
            python
            nums = [10, 20, 30]
            for i in range(len(nums)):
                print(i, nums[i])
            Scenario B: Using enumerate
            python
            for index, value in enumerate(nums):
                print(index, value)
            Scenario C: Custom start index
            python
            for index, value in enumerate(nums, start=1):
                print(index, value)
============================================
Task 6 — Looping Through Nested Lists
            Scenario A: 2D list
            python
            matrix = [
                [1, 2],
                [3, 4]
            ]

            for row in matrix:
                for col in row:
                    print(col)
            Scenario B: Irregular nested list
            python
            data = [[1], [2, 3], [4, 5, 6]]
            for row in data:
                for item in row:
                    print(item)
            Scenario C: Nested list with indexes
            python
            for i in range(len(matrix)):
                for j in range(len(matrix[i])):
                    print(i, j, matrix[i][j])
============================================
Task 7 — Loop + Condition Combinations
              Scenario A: Print even numbers
              python
              for x in range(10):
                  if x % 2 == 0:
                      print(x)
              Scenario B: Filter list
              python
              nums = [1, 2, 3, 4, 5]
              evens = []
              for x in nums:
                  if x % 2 == 0:
                      evens.append(x)
              Scenario C: Count items meeting condition
              python
              count = 0
              for x in nums:
                  if x > 3:
                      count += 1
============================================
Task 8 — Accumulators (sum, count, build lists)
              Scenario A: Sum
              python
              total = 0
              for x in [1, 2, 3]:
                  total += x
              Scenario B: Count
              python
              count = 0
              for x in [1, 2, 3, 4]:
                  if x % 2 == 0:
                      count += 1
              Scenario C: Build new list
              python
              squares = []
              for x in range(5):
                  squares.append(x*x)
============================================
Task 9 — Infinite Loop Patterns (Safe Examples)
          Scenario A: Controlled infinite loop
          python
          while True:
              print("Running...")
              break
          Scenario B: Loop until condition met
          python
          while True:
              x = int(input("Enter 0 to stop: "))
              if x == 0:
                  break
============================================
Task 10 — Looping with else
              Scenario A: for‑else
              python
              for x in range(5):
                  print(x)
              else:
                  print("Loop completed")
              Scenario B: break prevents else
              python
              for x in range(5):
                  if x == 2:
                      break
              else:
                  print("This will NOT run")
              Scenario C: while‑else
              python
              i = 0
              while i < 3:
                  print(i)
                  i += 1
              else:
                  print("Done")
============================================
🎯 2. 20 Questions — LOOPS

                Write a for loop to print numbers 0–4.
                Write a while loop to print numbers 1–5.
                Use a for loop to print each character in "Python".
                Use a while loop to count down from 5 to 1.
                Use break to stop a loop when x == 3.
                Use continue to skip printing the number 2.
                Loop through a list and print each element.
                Loop through a list using indexes.
                Loop through a list using enumerate.
                Loop through a range from 2 to 10.
                Loop through a range with step 2.
                Loop backward from 10 to 1.
                Loop through a nested list and print all values.
                Count how many numbers in a list are even.
                Build a list of squares from 0 to 4.
                Sum all numbers in a list.
                Write a loop that stops when user enters 0.
                Write a for‑else loop that prints “Done” after finishing.
                Write a loop that prints only numbers greater than 5.
                Write a loop that prints the index and value of each element.

# %%
####⭐ TOPIC 7 — FUNCTIONS

Tasks:

Define functions
Return values
Arguments & keyword arguments
Default arguments
Variable‑length arguments (*args, **kwargs)
Functions calling other functions
Scope (local vs global)
Lambda functions
Higher‑order functions (functions as arguments)
Docstrings
============================================

✅ 1. Multi‑Scenario Examples for Each Task
Task 1 — Define Functions
                Scenario A: Basic function
                python
                def greet():
                    print("Hello!")
                Scenario B: Function with parameters
                python
                def greet(name):
                    print(f"Hello, {name}")
                Scenario C: Function with multiple parameters
                python
                def add(a, b):
                    return a + b
                Scenario D: Function with no body (placeholder)
                python
                def todo():
                    pass
============================================
Task 2 — Return Values
            Scenario A: Simple return
            python
            def square(x):
                return x * x
            Scenario B: Multiple return values
            python
            def stats(a, b):
                return a + b, a * b
            Scenario C: Returning lists
            python
            def get_evens(nums):
                return [x for x in nums if x % 2 == 0]
            Scenario D: Early return
            python
            def check(n):
                if n < 0:
                    return "Negative"
                return "Positive"
============================================
Task 3 — Arguments & Keyword Arguments
              Scenario A: Positional arguments
              python
              def power(base, exp):
                  return base ** exp

              power(2, 3)
              Scenario B: Keyword arguments
              python
              power(exp=3, base=2)
              Scenario C: Mixed usage
              python
              power(2, exp=5)
              Scenario D: Incorrect usage
              python
              power(base=2, 3)   # ❌ SyntaxError
============================================
Task 4 — Default Arguments
              Scenario A: Default parameter
              python
              def greet(name="Guest"):
                  print(f"Hello, {name}")
              Scenario B: Multiple defaults
              python
              def connect(host="localhost", port=3306):
                  return f"Connecting to {host}:{port}"
              Scenario C: Default list (dangerous!)
              python
              def add_item(item, lst=[]):
                  lst.append(item)
                  return lst

              add_item(1)  # [1]
              add_item(2)  # [1, 2]  <-- shared list!
              Scenario D: Safe version
              python
              def add_item(item, lst=None):
                  if lst is None:
                      lst = []
                  lst.append(item)
                  return lst
============================================
Task 5 — Variable‑Length Arguments (*args, **kwargs)
                *Scenario A: args
                python
                def total(*nums):
                    return sum(nums)

                total(1, 2, 3)
                **Scenario B: kwargs
                python
                def show(**info):
                    for k, v in info.items():
                        print(k, v)

                show(name="Anu", age=20)
                Scenario C: Combined
                python
                def func(a, *args, **kwargs):
                    print(a, args, kwargs)

                func(1, 2, 3, x=10, y=20)
============================================
Task 6 — Functions Calling Other Functions
              Scenario A
              python
              def square(x):
                  return x*x

              def sum_of_squares(a, b):
                  return square(a) + square(b)
              Scenario B: Helper functions
              python
              def is_even(n):
                  return n % 2 == 0

              def filter_evens(nums):
                  return [x for x in nums if is_even(x)]
============================================
Task 7 — Scope (Local vs Global)

              Scenario A: Local variable
              python
              def func():
                  x = 10
                  return x
              Scenario B: Global variable
              python
              x = 5
              def func():
                  print(x)
              Scenario C: Modifying global variable
              python
              x = 5
              def func():
                  global x
                  x = 20
              Scenario D: Shadowing
              python
              x = 10
              def func():
                  x = 5
                  print(x)  # local 5
============================================
Task 8 — Lambda Functions
              Scenario A: Simple lambda
              python
              square = lambda x: x*x
              Scenario B: Lambda with multiple args
              python
              add = lambda a, b: a + b
              Scenario C: Lambda inside sort
              python
              names = ["Anu", "Bhavya", "Chandra"]
              names.sort(key=lambda x: len(x))
              Scenario D: Lambda in map
              python
              list(map(lambda x: x*2, [1,2,3]))
============================================
Task 9 — Higher‑Order Functions
              Scenario A: Passing function as argument
              python
              def apply(func, x):
                  return func(x)

              apply(lambda x: x*x, 5)
              Scenario B: Returning functions
              python
              def multiplier(n):
                  return lambda x: x*n

              double = multiplier(2)
              double(5)   # 10
============================================
Task 10 — Docstrings
            Scenario A: Basic docstring
            python
            def add(a, b):
                """Returns the sum of a and b."""
                return a + b
            Scenario B: Multi‑line docstring
            python
            def greet(name):
                """
                Greets a user by name.
                Parameters:
                    name (str): The user's name.
                """
                print(f"Hello {name}")
============================================
🎯 2. 20 Questions — FUNCTIONS

                Define a function named hello that prints "Hello".
                Write a function that returns the square of a number.
                Write a function that takes two numbers and returns their sum.
                Call a function using keyword arguments.
                Write a function with a default parameter.
                Write a function that returns multiple values.
                Write a function that filters even numbers from a list.
                Write a function that calls another function.
                Write a function using *args.
                Write a function using **kwargs.
                Write a function that returns a list of squares.
                Write a lambda function that doubles a number.
                Sort a list of strings by length using a lambda.
                Write a function that returns another function.
                Explain the difference between local and global variables.
                Write a function that modifies a global variable.
                Write a function with a docstring.
                Write a function that checks if a number is prime.
                Write a function that counts vowels in a string.
                Write a function that takes a list and returns only unique elements.

# %%
####⭐ TOPIC 8 — CLASSES & OBJECTS

Tasks:

Create a class
Define methods
Instantiate objects
Use attributes
Class vs instance attributes
Constructors (__init__)
Special methods (__str__, __repr__)
Encapsulation (private attributes)
Inheritance
Method overriding
Composition (object inside object)
Class methods & static methods
============================================

✅ 1. Multi‑Scenario Examples for Each Task
Task 1 — Create a Class
            Scenario A: Basic class
            python
            class Person:
                pass
            Scenario B: Class with docstring
            python
            class Car:
                """Represents a car object."""
                pass
            Scenario C: Class with default attributes
            python
            class User:
                role = "guest"
============================================
Task 2 — Define Methods
              Scenario A: Simple method
              python
              class Person:
                  def greet(self):
                      print("Hello!")
              Scenario B: Method with parameters
              python
              class Math:
                  def add(self, a, b):
                      return a + b
              Scenario C: Method modifying instance state
              python
              class Counter:
                  def __init__(self):
                      self.count = 0

                  def increment(self):
                      self.count += 1
============================================
Task 3 — Instantiate Objects
              Scenario A
              python
              p = Person()
              Scenario B: Multiple objects
              python
              p1 = Person()
              p2 = Person()
              Scenario C: Objects with different states
              python
              c1 = Counter()
              c2 = Counter()
              c1.increment()
============================================
Task 4 — Use Attributes
            Scenario A: Setting attributes
            python
            p.name = "Anu"
            p.age = 20
            Scenario B: Accessing attributes
            python
            print(p.name)
            Scenario C: Updating attributes
            python
            p.age += 1
============================================
Task 5 — Class vs Instance Attributes
            Scenario A: Class attribute
            python
            class Dog:
                species = "Canine"
            Scenario B: Instance attribute
            python
            d1 = Dog()
            d1.name = "Buddy"
            Scenario C: Class attribute shared
            python
            d2 = Dog()
            print(d1.species, d2.species)
            Scenario D: Overriding class attribute
            python
            d1.species = "Wolf"
============================================
Task 6 — Constructors (__init__)
          Scenario A: Basic constructor
          python
          class Person:
              def __init__(self, name):
                  self.name = name
          Scenario B: Multiple parameters
          python
          class Point:
              def __init__(self, x, y):
                  self.x = x
                  self.y = y
          Scenario C: Default values
          python
          class User:
              def __init__(self, name, role="guest"):
                  self.name = name
                  self.role = role
============================================
Task 7 — Special Methods (__str__, __repr__)
          Scenario A: str
          python
          class Person:
              def __init__(self, name):
                  self.name = name

              def __str__(self):
                  return f"Person({self.name})"
          Scenario B: repr
          python
          class Point:
              def __repr__(self):
                  return "Point(x={}, y={})".format(self.x, self.y)
          Scenario C: Both
          python
          class Book:
              def __str__(self):
                  return "Readable format"

              def __repr__(self):
                  return "Developer format"
============================================
Task 8 — Encapsulation (Private Attributes)
            Scenario A: Private attribute
            python
            class Bank:
                def __init__(self):
                    self.__balance = 0
            Scenario B: Getter
            python
            def get_balance(self):
                return self.__balance
            Scenario C: Setter
            python
            def deposit(self, amount):
                self.__balance += amount
============================================
Task 9 — Inheritance
              Scenario A: Basic inheritance
              python
              class Animal:
                  def speak(self):
                      print("Sound")

              class Dog(Animal):
                  pass
              Scenario B: Adding new methods
              python
              class Cat(Animal):
                  def meow(self):
                      print("Meow")
              Scenario C: Multi‑level inheritance
              python
              class A: pass
              class B(A): pass
              class C(B): pass
============================================
Task 10 — Method Overriding
            Scenario A
            python
            class Animal:
                def speak(self):
                    print("Sound")

            class Dog(Animal):
                def speak(self):
                    print("Bark")
            Scenario B: Calling parent method
            python
            class Dog(Animal):
                def speak(self):
                    super().speak()
                    print("Bark")
============================================
Task 11 — Composition (Object Inside Object)
            Scenario A
            python
            class Engine:
                def start(self):
                    print("Engine started")

            class Car:
                def __init__(self):
                    self.engine = Engine()
            Scenario B: Using composed object
            python
            c = Car()
            c.engine.start()
============================================
Task 12 — Class Methods & Static Methods
            Scenario A: Class method
            python
            class Person:
                count = 0

                @classmethod
                def increment_count(cls):
                    cls.count += 1
            Scenario B: Static method
            python
            class Math:
                @staticmethod
                def add(a, b):
                    return a + b
            Scenario C: Using both
            python
            Person.increment_count()
            Math.add(2, 3)
============================================
🎯 2. 20 Questions — CLASSES & OBJECTS

Create a class named Person.
Add a method greet() that prints "Hello".
Create an object of the Person class.
Add an attribute name to an object.
Write a constructor that takes name and age.
Create a class attribute species = "Human".
Create an instance attribute self.city.
Override a method in a child class.
Create a class Animal and a subclass Dog.
Add a method bark() to Dog.
Write a __str__ method for a class.
Write a __repr__ method for a class.
Create a private attribute __balance.
Write a getter for the private attribute.
Write a setter that updates the private attribute.
Demonstrate composition using Car and Engine.
Write a class method that increments a counter.
Write a static method that multiplies two numbers.
Create two objects with different states.
Explain the difference between class and instance attributes.

# %%
####⭐ TOPIC 9 — DICTIONARIES

Tasks:

Create dictionaries
Access/update keys
Add/remove key‑value pairs
Iterate over items
Check for key existence
Dictionary methods (get, keys, values, items, pop, update)
Nested dictionaries
Dictionary comprehension
Copying dictionaries (shallow vs deep)
Using dictionaries in loops
============================================
✅ 1. Multi‑Scenario Examples for Each Task

Task 1 — Create Dictionaries

            Scenario A: Basic dictionary
            python
            user = {"name": "Anu", "age": 20}
            Scenario B: Empty dictionary
            python
            data = {}
            Scenario C: Using dict()
            python
            info = dict(city="Seattle", country="USA")
            Scenario D: Mixed types
            python
            record = {"id": 1, "scores": [90, 85], "active": True}
============================================
Task 2 — Access / Update Keys

            Scenario A: Access value
            python
            user["name"]   # "Anu"
            Scenario B: Update value
            python
            user["age"] = 21
            Scenario C: Add new key
            python
            user["role"] = "Architect"
            Scenario D: Access with get()
            python
            user.get("email")   # None (safe)
============================================
Task 3 — Add / Remove Key‑Value Pairs
            Scenario A: Add
            python
            user["email"] = "anu@example.com"
            Scenario B: Remove using pop
            python
            user.pop("age")
            Scenario C: Remove using del
            python
            del user["role"]
            Scenario D: Remove last inserted item (Python 3.7+)
            python
            user.popitem()
============================================
Task 4 — Iterate Over Items

            Scenario A: Iterate keys
            python
            for key in user:
                print(key)
            Scenario B: Iterate values
            python
            for value in user.values():
                print(value)
            Scenario C: Iterate key‑value pairs
            python
            for key, value in user.items():
                print(key, value)
============================================
Task 5 — Check for Key Existence
            Scenario A
            python
            "name" in user
            Scenario B
            python
            if "email" not in user:
                user["email"] = "unknown"
============================================
Task 6 — Dictionary Methods
            Scenario A: get()
            python
            user.get("age", "Not provided")
            Scenario B: update()
            python
            user.update({"city": "Bellevue"})
            Scenario C: keys(), values(), items()
            python
            user.keys()
            user.values()
            user.items()
            Scenario D: pop() with default
            python
            user.pop("salary", 0)
============================================
Task 7 — Nested Dictionaries
              Scenario A
              python
              student = {
                  "name": "Anu",
                  "scores": {"math": 95, "science": 90}
              }
              Scenario B: Access nested value
              python
              student["scores"]["math"]
              Scenario C: Update nested value
              python
              student["scores"]["science"] = 92
              Scenario D: Deep nesting
              python
              company = {
                  "dept": {
                      "team": {
                          "lead": "Anu"
                      }
                  }
              }
              company["dept"]["team"]["lead"]
============================================
Task 8 — Dictionary Comprehension
            Scenario A: Basic
            python
            squares = {x: x*x for x in range(5)}
            Scenario B: Filtered comprehension
            python
            evens = {x: x*x for x in range(10) if x % 2 == 0}
            Scenario C: Transforming values
            python
            names = ["anu", "bhavya", "chandra"]
            caps = {name: name.upper() for name in names}
============================================
Task 9 — Copying Dictionaries (Shallow vs Deep)
            Scenario A: Shallow copy
            python
            a = {"x": 1, "y": [1, 2]}
            b = a.copy()
            a["y"].append(3)
            # b["y"] also changes
            Scenario B: Deep copy
            python
            import copy
            a = {"x": 1, "y": [1, 2]}
            b = copy.deepcopy(a)
            a["y"].append(3)
            # b["y"] stays unchanged
============================================
Task 10 — Using Dictionaries in Loops
            Scenario A: Counting occurrences
            python
            text = "banana"
            freq = {}
            for ch in text:
                freq[ch] = freq.get(ch, 0) + 1
            Scenario B: Building dictionary from list
            python
            nums = [1, 2, 3]
            squares = {}
            for n in nums:
                squares[n] = n*n
            Scenario C: Reverse lookup
            python
            for key, value in user.items():
                if value == "Anu":
                    print("Found key:", key)
============================================
🎯 2. 20 Questions — DICTIONARIES

Create a dictionary with keys "name" and "age".
Access the value of "name" from a dictionary.
Update the "age" key to 25.
Add a new key "city" with value "Seattle".
Remove the key "age" using pop().
Remove the key "city" using del.
Check if "email" exists in a dictionary.
Use get() to safely access "email".
Iterate over dictionary keys.
Iterate over dictionary values.
Iterate over key‑value pairs.
Create a nested dictionary for a student with subject scores.
Access a nested value from a dictionary.
Update a nested value.
Create a dictionary comprehension that maps numbers to their squares.
Create a filtered dictionary comprehension for even numbers.
Copy a dictionary using copy().
Explain shallow vs deep copy.
Use update() to add multiple keys.
Count character frequencies in a string using a dictionary.

# %%
####⭐ TOPIC 10 — MODULES & PACKAGES

Tasks:

Import modules
Use functions from modules
Create your own module
Create your own package
Import with aliases
Selective imports (from module import name)
Importing everything (from module import *)
Using __name__ == "__main__"
Module search path (sys.path)
Reloading modules
============================================
✅ 1. Multi‑Scenario Examples for Each Task

Task 1 — Import Modules

          Scenario A: Basic import
          python
          import math
          Scenario B: Import multiple modules
          python
          import os, sys
          Scenario C: Import inside a function
          python
          def compute():
              import random
              return random.randint(1, 10)
          Scenario D: Conditional import
          python
          if True:
              import json
============================================
Task 2 — Use Functions from Modules
          Scenario A: Using math module
          python
          import math
          math.sqrt(25)
          math.pi
          Scenario B: Using random module
          python
          import random
          random.choice([1, 2, 3])
          Scenario C: Using datetime
          python
          from datetime import datetime
          datetime.now()
          Scenario D: Using os module
          python
          import os
          os.listdir(".")
============================================
Task 3 — Create Your Own Module
          Scenario A: Create a file mymath.py
          python
          # mymath.py
          def add(a, b):
              return a + b
          Scenario B: Import your module
          python
          import mymath
          mymath.add(2, 3)
          Scenario C: Selective import
          python
          from mymath import add
          add(5, 6)
============================================
Task 4 — Create Your Own Package
          Scenario A: Folder structure
          Code
          mypackage/
              __init__.py
              utils.py
              mathops.py
          Scenario B: Import from package
          python
          from mypackage.utils import helper
          Scenario C: Using init.py
          python
          # __init__.py
          from .utils import helper
============================================
Task 5 — Import with Aliases
          Scenario A
          python
          import numpy as np
          Scenario B
          python
          import math as m
          m.sqrt(16)
============================================
Task 6 — Selective Imports
          Scenario A
          python
          from math import sqrt
          sqrt(25)
          Scenario B: Multiple selective imports
          python
          from math import sin, cos, tan
          Scenario C: Rename imported function
          python
          from math import factorial as fact
          fact(5)
============================================
Task 7 — Import Everything (from module import *)
              Scenario A
              python
              from math import *
              print(pi)
              Scenario B: Why it’s dangerous
              Pollutes namespace

              Hard to track where names come from

              Can override built‑ins
============================================
Task 8 — Using __name__ == "__main__"
              Scenario A: Basic usage
              python
              # myscript.py
              def run():
                  print("Running script")

              if __name__ == "__main__":
                  run()
              Scenario B: Prevent code from running on import
              python
              # Only runs when executed directly
============================================
Task 9 — Module Search Path (sys.path)
              Scenario A
              python
              import sys
              print(sys.path)
              Scenario B: Add custom path
              python
              sys.path.append("/my/custom/path")
============================================
Task 10 — Reloading Modules
            Scenario A
            python
            import importlib
            import mymodule
            importlib.reload(mymodule)
            Scenario B: Useful during development
            When editing modules

            Avoid restarting interpreter
============================================
🎯 2. 20 Questions — MODULES & PACKAGES

Import the math module.
Use math.sqrt() to compute the square root of 49.
Import only the pi constant from math.
Import random with alias rnd.
Use random.choice() to pick a random element.
Create a module named utils.py with a function greet().
Import the greet() function from utils.
Create a package with __init__.py.
Import a function from a package submodule.
Explain why from module import * is dangerous.
Use __name__ == "__main__" in a script.
Print the module search path.
Add a custom path to sys.path.
Reload a module using importlib.reload().
Import multiple functions from a module in one line.
Create a module with two functions and import both.
Use os.listdir() to list files.
Use datetime.now() to print current time.
Create a package with two modules and import both.
Explain the difference between a module and a package.

# %%
####⭐ TOPIC 11 — LIST COMPREHENSIONS

Tasks:

Build lists using comprehension
Add conditions inside comprehensions
Nested list comprehensions
Transforming values
Filtering values
Using functions inside comprehensions
Using if/else inside comprehensions
Flattening lists
Dictionary → list transformations
Combining multiple iterables
============================================
✅ 1. Multi‑Scenario Examples for Each Task

Task 1 — Build Lists Using Comprehension
            Scenario A: Basic comprehension
            python
            nums = [x for x in range(5)]
            # [0, 1, 2, 3, 4]
            Scenario B: Squares
            python
            squares = [x*x for x in range(6)]
            Scenario C: Characters from string
            python
            chars = [c for c in "Python"]
            Scenario D: Copying a list
            python
            copy = [x for x in [1,2,3]]
============================================
Task 2 — Add Conditions Inside Comprehensions
              Scenario A: Even numbers
              python
              evens = [x for x in range(10) if x % 2 == 0]
              Scenario B: Filter strings
              python
              names = ["Anu", "Bhavya", "Chandra"]
              short = [n for n in names if len(n) <= 4]
              Scenario C: Filter based on type
              python
              mixed = [1, "a", 2, "b"]
              nums = [x for x in mixed if isinstance(x, int)]
============================================
Task 3 — Nested List Comprehensions
              Scenario A: Flatten 2D list
              python
              matrix = [[1,2],[3,4]]
              flat = [x for row in matrix for x in row]
              Scenario B: Multiply pairs
              python
              pairs = [(i,j) for i in range(3) for j in range(3)]
              Scenario C: Filter inside nested
              python
              evens = [x for row in matrix for x in row if x % 2 == 0]
============================================
Task 4 — Transforming Values
              Scenario A: Uppercase strings
              python
              names = ["anu", "bhavya"]
              upper = [n.upper() for n in names]
              Scenario B: Convert numbers to strings
              python
              nums = [1,2,3]
              strings = [str(x) for x in nums]
              Scenario C: Extract first letter
              python
              first_letters = [name[0] for name in names]
============================================
Task 5 — Filtering Values
              Scenario A: Remove empty strings
              python
              clean = [s for s in ["a", "", "b"] if s]
              Scenario B: Keep only positive numbers
              python
              nums = [-2, -1, 0, 1, 2]
              positive = [x for x in nums if x > 0]
============================================
Task 6 — Using Functions Inside Comprehensions
              Scenario A
              python
              def square(x): return x*x
              squares = [square(x) for x in range(5)]
              Scenario B: Using built‑ins
              python
              lengths = [len(name) for name in ["Anu", "Bhavya"]]
============================================
Task 7 — Using if/else Inside Comprehensions
              Scenario A: Even/odd labels
              python
              labels = ["even" if x % 2 == 0 else "odd" for x in range(5)]
              Scenario B: Replace negatives with 0
              python
              nums = [-3, 2, -1, 5]
              fixed = [x if x > 0 else 0 for x in nums]
============================================
Task 8 — Flattening Lists
              Scenario A: Flatten 2D list
              python
              flat = [x for row in [[1,2],[3,4]] for x in row]
              Scenario B: Flatten irregular list
              python
              data = [[1], [2,3], [4,5,6]]
              flat = [x for row in data for x in row]
============================================
Task 9 — Dictionary → List Transformations
              Scenario A: Keys
              python
              d = {"a":1, "b":2}
              keys = [k for k in d]
              Scenario B: Values
              python
              values = [v for v in d.values()]
              Scenario C: Key‑value pairs
              python
              pairs = [(k,v) for k,v in d.items()]
              Scenario D: Filter dictionary
              python
              filtered = [k for k,v in d.items() if v > 1]
============================================
Task 10 — Combining Multiple Iterables
              Scenario A: Combine lists
              python
              a = [1,2]
              b = [3,4]
              combined = [x+y for x in a for y in b]
              Scenario B: Zip inside comprehension
              python
              names = ["Anu", "Bhavya"]
              ages = [20, 25]
              pairs = [(n,a) for n,a in zip(names, ages)]
              Scenario C: Cartesian product
              python
              product = [(x,y) for x in range(3) for y in range(3)]
============================================
🎯 2. 20 Questions — LIST COMPREHENSIONS

              Create a list of numbers from 0 to 9 using comprehension.
              Create a list of squares from 0 to 5.
              Extract characters from the string "Python" into a list.
              Filter even numbers from a list.
              Filter names with length > 4.
              Convert all strings in a list to uppercase.
              Replace negative numbers with 0 using comprehension.
              Create a list of tuples (x, x*x) for x in range(5).
              Flatten a 2D list using comprehension.
              Create a list of even squares from 0 to 10.
              Use a function inside a comprehension.
              Create a list of first letters from a list of names.
              Build a list of numbers divisible by 3.
              Create a list of (name, length) pairs.
              Filter dictionary keys where value > 10.
              Convert dictionary items into a list of tuples.
              Build a list of odd numbers using comprehension.
              Create a list of "even" or "odd" labels for numbers 0–10.
              Combine two lists using nested comprehension.
              Use zip inside a comprehension to pair names and ages.

# %%
####⭐ TOPIC 12 — REGULAR EXPRESSIONS

Tasks:

              Match patterns
              Use re.search, re.match, re.findall
              Replace text (re.sub)
              Character classes
              Quantifiers
              Anchors (^, $)
              Groups & capturing
              Non‑capturing groups
              Alternation (|)
              Special sequences (\d, \w, \s)
              Raw strings (r"...")
              Compiling regex patterns

============================================
✅ 1. Multi‑Scenario Examples for Each Task

Task 1 — Match Patterns
              Scenario A: Basic match
              python
              import re
              re.match(r"abc", "abcdef")   # matches 'abc'
              Scenario B: No match
              python
              re.match(r"xyz", "abcdef")   # None
              Scenario C: Full string match
              python
              re.fullmatch(r"\d{3}", "123")   # matches
============================================
Task 2 — re.search, re.match, re.findall
            Scenario A: re.match (only at start)
            python
            re.match(r"cat", "catapult")   # match
            re.match(r"cat", "concatenate") # None
            Scenario B: re.search (anywhere)
            python
            re.search(r"cat", "concatenate")  # match
            Scenario C: re.findall (all occurrences)
            python
            re.findall(r"\d+", "Age 20, Score 95")
            # ['20', '95']
            Scenario D: re.finditer
            python
            for m in re.finditer(r"\d+", "A1 B22 C333"):
                print(m.group(), m.start(), m.end())
============================================
Task 3 — Replace Text (re.sub)

            Scenario A: Replace digits
            python
            re.sub(r"\d", "*", "A1B2C3")
            # 'A*B*C*'
            Scenario B: Replace multiple spaces
            python
            re.sub(r"\s+", " ", "Hello   world")
            Scenario C: Mask email
            python
            re.sub(r"(\w+)@(\w+)", r"***@\2", "anu@example")
============================================
Task 4 — Character Classes
            Scenario A: Digits
            python
            re.findall(r"[0-9]", "a1b2c3")
            Scenario B: Letters
            python
            re.findall(r"[A-Za-z]", "A1b2C3")
            Scenario C: Negated class
            python
            re.findall(r"[^0-9]", "a1b2c3")
============================================
Task 5 — Quantifiers
                Scenario A: * zero or more
                python
                re.findall(r"ab*", "abbb a ac")
                # ['abbb', 'a']
                Scenario B: + one or more
                python
                re.findall(r"ab+", "abbb a ac")
                # ['abbb']
                Scenario C: ? zero or one
                python
                re.findall(r"ab?", "abbb a ac")
                # ['ab', 'a', 'a']
                Scenario D: Exact count
                python
                re.findall(r"\d{3}", "123 45 678")
                # ['123', '678']
                Scenario E: Range count
                python
                re.findall(r"\d{2,4}", "1 12 123 1234 12345")
============================================
Task 6 — Anchors (^, $)
                Scenario A: Starts with
                python
                re.match(r"^Hello", "Hello world")
                Scenario B: Ends with
                python
                re.search(r"world$", "Hello world")
                Scenario C: Validate full string
                python
                re.fullmatch(r"\d{4}", "2024")
============================================
Task 7 — Groups & Capturing
                Scenario A: Basic groups
                python
                m = re.search(r"(\d{3})-(\d{2})", "123-45")
                m.group(1)  # '123'
                m.group(2)  # '45'
                Scenario B: Named groups
                python
                m = re.search(r"(?P<area>\d{3})-(?P<num>\d{4})", "425-1234")
                m.group("area")  # '425'
                Scenario C: Extracting email parts
                python
                re.search(r"(\w+)@(\w+)", "anu@example.com").groups()
============================================
Task 8 — Non‑Capturing Groups
                Scenario A
                python
                re.findall(r"(?:ab)+", "ababab")
                # ['ababab']
                Scenario B: Useful in alternation
                python
                re.findall(r"(?:cat|dog)", "cat dog cat")
============================================
Task 9 — Alternation (|)
                Scenario A
                python
                re.findall(r"cat|dog", "cat dog cat")
                Scenario B: Multiple options
                python
                re.findall(r"red|green|blue", "red green blue yellow")
============================================
Task 10 — Special Sequences (\d, \w, \s)
                Scenario A: Digits
                python
                re.findall(r"\d", "a1b2c3")
                Scenario B: Word characters
                python
                re.findall(r"\w", "A1_b")
                Scenario C: Whitespace
                python
                re.findall(r"\s", "Hello world")
============================================
Task 11 — Raw Strings (r"...")
                Scenario A: Without raw string
                python
                "\\d"   # double escaping
                Scenario B: With raw string
                python
                r"\d"   # clean
                Scenario C: Why raw strings matter
                python
                re.findall(r"\d+", "123")
============================================
Task 12 — Compiling Regex Patterns
                Scenario A
                python
                pattern = re.compile(r"\d+")
                pattern.findall("123 456")
                Scenario B: Reuse compiled pattern
                python
                p = re.compile(r"[A-Z]+")
                p.findall("ABC def GHI")
                Scenario C: Flags
                python
                p = re.compile(r"hello", re.IGNORECASE)
                p.findall("Hello HELLO hello")
============================================
🎯 2. 20 Questions — REGULAR EXPRESSIONS

                Write a regex to match "cat" at the start of a string.
                Write a regex to match any 3‑digit number.
                Use re.search() to find "dog" in "hotdog".
                Use re.findall() to extract all numbers from "Age 20, Score 95".
                Replace all digits in "A1B2C3" with "*".
                Write a regex to match only lowercase letters.
                Write a regex to match one or more digits.
                Write a regex to match exactly 4 digits.
                Write a regex to match "cat" or "dog".
                Extract username and domain from "anu@example.com".
                Write a regex to match strings ending with "ing".
                Use a named group to capture a phone area code.
                Write a regex to match whitespace characters.
                Write a regex to match non‑digit characters.
                Write a regex to match a word character (\w).
                Use re.sub() to remove extra spaces.
                Write a regex to match a valid 24‑hour time (HH:MM).
                Compile a regex and use it multiple times.
                Write a regex to extract all capital words.
                Write a regex to validate a 5‑digit ZIP code.

# %%
####TOPIC 13 — EXCEPTION HANDLING
Tasks:

                Use try/except
                Handle multiple exception types
                Use else with try
                Use finally
                Raise exceptions manually
                Custom exception classes
                Nested try/except
                Exception chaining
                Catching broad vs specific exceptions
                Logging exceptions
                Using assert
                Best practices
============================================
✅ 1. Multi‑Scenario Examples for Each Task

Task 1 — Use try/except

                Scenario A: Basic try/except
                python
                try:
                    x = 10 / 0
                except ZeroDivisionError:
                    print("Cannot divide by zero")
                Scenario B: Catching any exception
                python
                try:
                    print(a)  # a is not defined
                except Exception:
                    print("Something went wrong")
                Scenario C: Handling input errors
                python
                try:
                    age = int("abc")
                except ValueError:
                    print("Invalid number")
============================================
Task 2 — Handle Multiple Exception Types
                Scenario A
                python
                try:
                    x = int("abc")
                except ValueError:
                    print("Value error")
                except TypeError:
                    print("Type error")
                Scenario B: Multiple exceptions in one block
                python
                try:
                    x = int("abc")
                except (ValueError, TypeError):
                    print("Invalid input")
============================================
Task 3 — Use else with try
                Scenario A
                python
                try:
                    x = int("25")
                except ValueError:
                    print("Error")
                else:
                    print("Success:", x)
                Scenario B: else runs only if no exception
                python
                try:
                    f = open("file.txt")
                except FileNotFoundError:
                    print("File missing")
                else:
                    print("File opened")
============================================
Task 4 — Use finally
              Scenario A
              python
              try:
                  f = open("file.txt")
              except:
                  print("Error opening file")
              finally:
                  print("Always runs")
              Scenario B: Closing resources
              python
              try:
                  f = open("data.txt")
                  data = f.read()
              except:
                  print("Error")
              finally:
                  f.close()
============================================
Task 5 — Raise Exceptions Manually
              Scenario A
              python
              def check_age(age):
                  if age < 0:
                      raise ValueError("Age cannot be negative")
              Scenario B: Raise TypeError
              python
              def add(a, b):
                  if not isinstance(a, int):
                      raise TypeError("a must be int")
============================================
Task 6 — Custom Exception Classes
              Scenario A
              python
              class InvalidAgeError(Exception):
                  pass
              Scenario B: Using custom exception
              python
              def set_age(age):
                  if age < 0:
                      raise InvalidAgeError("Negative age not allowed")
              Scenario C: Inheriting from Exception
              python
              class MyError(Exception):
                  def __init__(self, message):
                      super().__init__(message)
============================================
Task 7 — Nested try/except
                Scenario A
                python
                try:
                    try:
                        x = int("abc")
                    except ValueError:
                        print("Inner error")
                except Exception:
                    print("Outer error")
                Scenario B: Nested file operations
                python
                try:
                    f = open("data.txt")
                    try:
                        data = int(f.read())
                    except ValueError:
                        print("Invalid number in file")
                finally:
                    f.close()
============================================
Task 8 — Exception Chaining
                Scenario A
                python
                try:
                    int("abc")
                except ValueError as e:
                    raise RuntimeError("Conversion failed") from e
                Scenario B: Without chaining
                python
                raise RuntimeError("Error occurred")
============================================
Task 9 — Catching Broad vs Specific Exceptions
                Scenario A: Specific first
                python
                try:
                    x = 10 / 0
                except ZeroDivisionError:
                    print("Zero division")
                except Exception:
                    print("General error")
                Scenario B: Bad practice
                python
                try:
                    risky()
                except Exception:
                    print("Too broad")
============================================
Task 10 — Logging Exceptions
                Scenario A
                python
                import logging

                try:
                    1 / 0
                except Exception as e:
                    logging.error("Error occurred: %s", e)
                Scenario B: Logging stack trace
                python
                logging.exception("Exception happened")
============================================
Task 11 — Using assert
              Scenario A
              python
              assert 5 > 3
              Scenario B: Assertion with message
              python
              assert age >= 0, "Age cannot be negative"
              Task 12 — Best Practices
              Scenario A: Minimal try block
              python
              try:
                  risky_operation()
              except Exception:
                  handle()
              Scenario B: Avoid bare except
              python
              except Exception:
                  ...
              Scenario C: Use finally for cleanup
              python
              finally:
                  close_resources()
============================================
🎯 2. 20 Questions — EXCEPTION HANDLING

                  Write a try/except block to catch division by zero.
                  Catch a ValueError when converting "abc" to int.
                  Write a try/except/else block.
                  Write a try/finally block.
                  Raise a ValueError if age < 0.
                  Create a custom exception class.
                  Raise your custom exception.
                  Catch multiple exceptions in one except block.
                  Use re.match() inside try/except.
                  Use nested try/except blocks.
                  Use exception chaining with from.
                  Log an exception using logging.error().
                  Use assert to check if a number is positive.
                  Write a function that catches and prints exceptions.
                  Write a try block that only wraps one risky line.
                  Catch a TypeError in a function.
                  Use finally to close a file.
                  Explain why bare except: is bad practice.
                  Write a try block that handles file not found.
                  Write a try block that handles invalid dictionary key access.

# %%
#####⭐ TOPIC 14 — SETS

Tasks:

            Create sets
            Add/remove elements
            Union, intersection, difference
            Set membership
            Set operations with operators (|, &, -, ^)
            Iterate through sets
            Convert between list and set
            Remove duplicates using sets
            Frozen sets
            Set comprehension

============================================

✅ 1. Multi‑Scenario Examples for Each Task

Task 1 — Create Sets
            Scenario A: Basic set
            python
            s = {1, 2, 3}
            Scenario B: Empty set
            python
            s = set()   # {} is a dict, not a set
            Scenario C: Mixed types
            python
            s = {1, "Anu", 3.14, True}
            Scenario D: From list
            python
            s = set([1, 2, 2, 3])   # {1, 2, 3}
============================================
Task 2 — Add / Remove Elements
            Scenario A: Add
            python
            s.add(4)
            Scenario B: Remove (error if missing)
            python
            s.remove(2)
            Scenario C: Discard (safe remove)
            python
            s.discard(10)   # no error
            Scenario D: Pop (random element)
            python
            s.pop()
            Scenario E: Clear
            python
            s.clear()
============================================
Task 3 — Union, Intersection, Difference
            Scenario A: Union
            python
            a = {1, 2}
            b = {2, 3}
            a.union(b)   # {1, 2, 3}
            Scenario B: Intersection
            python
            a.intersection(b)   # {2}
            Scenario C: Difference
            python
            a.difference(b)   # {1}
            Scenario D: Symmetric difference
            python
            a.symmetric_difference(b)   # {1, 3}
============================================
Task 4 — Set Membership
            Scenario A
            python
            2 in {1,2,3}
            Scenario B
            python
            "Anu" not in {"Bhavya", "Chandra"}
============================================
Task 5 — Set Operators (|, &, -, ^)
            Scenario A: Union
            python
            {1,2} | {2,3}   # {1,2,3}
            Scenario B: Intersection
            python
            {1,2,3} & {2,3,4}   # {2,3}
            Scenario C: Difference
            python
            {1,2,3} - {2}   # {1,3}
            Scenario D: Symmetric difference
            python
            {1,2,3} ^ {3,4}   # {1,2,4}
============================================
Task 6 — Iterate Through Sets
            Scenario A
            python
            for x in {1,2,3}:
                print(x)
            Scenario B: Loop with condition
            python
            for x in {1,2,3,4}:
                if x % 2 == 0:
                    print("Even:", x)
============================================
Task 7 — Convert Between List and Set
            Scenario A: List → Set
            python
            s = set([1,2,2,3])
            Scenario B: Set → List
            python
            lst = list({1,2,3})
            Scenario C: Remove duplicates
            python
            unique = list(set([1,1,2,3,3]))
============================================
Task 8 — Remove Duplicates Using Sets
            Scenario A
            python
            nums = [1,2,2,3,3,3]
            unique = list(set(nums))
            Scenario B: Preserve order (advanced)
            python
            nums = [1,2,2,3,3,3]
            unique = list(dict.fromkeys(nums))
============================================
Task 9 — Frozen Sets
            Scenario A: Create frozenset
            python
            fs = frozenset([1,2,3])
            Scenario B: Use as dictionary key
            python
            d = {frozenset([1,2]): "pair"}
            Scenario C: Immutable
            python
            fs.add(4)   # ❌ AttributeError
============================================
Task 10 — Set Comprehension
            Scenario A: Basic
            python
            s = {x for x in range(5)}
            Scenario B: Filter
            python
            evens = {x for x in range(10) if x % 2 == 0}
            Scenario C: Transform
            python
            squares = {x*x for x in range(5)}
============================================
🎯 2. 20 Questions — SETS

Create a set with values 1, 2, 3.
Create an empty set.
Add the value 10 to a set.
Remove the value 2 from a set.
Use discard() to remove a value safely.
Pop an element from a set.
Clear all elements from a set.
Find the union of {1,2} and {2,3}.
Find the intersection of {1,2,3} and {2,3,4}.
Find the difference {1,2,3} - {2}.
Find the symmetric difference {1,2,3} and {3,4}.
Check if 5 is in a set.
Convert a list with duplicates to a set.
Convert a set to a list.
Remove duplicates from [1,1,2,3,3].
Create a frozenset.
Use a frozenset as a dictionary key.
Write a set comprehension for squares of 0–4.
Write a set comprehension for even numbers 0–10.
Iterate through a set and print each element.
